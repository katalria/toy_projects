# %% [markdown]
# # EDA 기초
#
# 지난 시간에는 PCA와 같은 몇몇 시각화 툴과 더불어 그래프의 용례에 대해 살펴보았습니다.
#
# 오늘은 본격적으로 시각화를 해보는 시간을 갖도록 할텐데요,
#
# 그 전에 지난 시간에 빠진 부분에 대해 살펴보고 넘어가도록 하겠습니다.
#
# [[링크]](https://towardsdatascience.com/the-5-clustering-algorithms-data-scientists-need-to-know-a36d136ef68)

# %% [markdown]
# PCA에 대해 더 자세히 알고 싶으신 분은 아래 링크를 참조하시기 바랍니다.
#
# [[링크]](https://pca4ds.github.io/)

# %% [markdown]
# ## Unit 7. 시각화
#
# Fundamental 9~11과 아래 링크를 참조해 진행해주세요
#
# [Matplotlib](https://wikidocs.net/book/5011)
#
# 오늘 데이터는 Fund 5의 과제로 나온 데이터입니다. 데이터에 대한 자세한 설명은 아래 링크를 참조해주세요.
#
# [Kaggle](https://www.kaggle.com/c/bike-sharing-demand/data)

# %% [markdown]
# ### 조별과제 1
#
# 조별로 힘을 합쳐 아래 노트북을 완성해주세요!

# %%
from sklearn.decomposition import PCA
from sklearn.datasets import load_digits
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import pandas as pd

import os

# %%
train = pd.read_csv('{}/aiffel/bike_sharing_demand_train.csv'.format(os.getenv('HOME')))
test = pd.read_csv('{}/aiffel/bike_sharing_demand_test.csv'.format(os.getenv('HOME')))
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %% [markdown]
# ### Step 1. 타입 변경
#
# **Fundamental 5. 날씨 좋은 월요일 오후 세 시, 자전거 타는 사람은 몇 명?** 를 참조하여 datetime 컬럼의 데이터타입을 변경해주세요.

# %%
train_copy = train.copy()
test_copy = test.copy()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
# <YOUR CODE>
train_copy['datetime']
# Out:
# 0        2011-01-01 00:00:00
# 1        2011-01-01 01:00:00
# 2        2011-01-01 02:00:00
# 3        2011-01-01 03:00:00
# 4        2011-01-01 04:00:00
#                 ...
# 10881    2012-12-19 19:00:00
# 10882    2012-12-19 20:00:00
# 10883    2012-12-19 21:00:00
# 10884    2012-12-19 22:00:00
# 10885    2012-12-19 23:00:00
# Name: datetime, Length: 10886, dtype: object

# %%
train_copy['datetime'] = pd.to_datetime(train_copy['datetime'])

# %%
train_copy['datetime']
# Out:
# 0       2011-01-01 00:00:00
# 1       2011-01-01 01:00:00
# 2       2011-01-01 02:00:00
# 3       2011-01-01 03:00:00
# 4       2011-01-01 04:00:00
#                 ...
# 10881   2012-12-19 19:00:00
# 10882   2012-12-19 20:00:00
# 10883   2012-12-19 21:00:00
# 10884   2012-12-19 22:00:00
# 10885   2012-12-19 23:00:00
# Name: datetime, Length: 10886, dtype: datetime64[ns]

# %%
test_copy['datetime'] = pd.to_datetime(test_copy['datetime'])

# %% [markdown]
# ### Step 2. 결측치 탐색
#
# 데이터를 살펴보다보면 datetime 컬럼에 info()만으로 발견할 수 없었던 결측치가 있을 것입니다.
#
# 그러한 결측치가 있다면 어떻게 채워넣을지 토의해보고 구현해봅시다.

# %%
## isna()로는 검출 x >> 데이터 하나씩 확인 필요
train_copy.isna().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %%
## datetime64
## 각 행의 날짜 데이터가 한시간 차이가 아닌 행의 index 추출하는 for loop
import datetime
count = 0
for i in range(len(train_copy))[1:]:
    if train_copy['datetime'][i] - datetime.timedelta(hours=1) != train_copy['datetime'][i-1]:
        print(i)
        count+=1
# Out:
# 29
# 49
# 72
# 95
# 118
# 141
# 236
# 258
# 305
# 396
# 411
# 431
# 435
# 482
# 505
# 624
# 646
# 669
# 717
# 762
# 784
# 877
# 1002
# 1022
# 1094
# 1117
# 1162
# 1187
# 1209
# 1231
# 1280
# 1323
# 1566
# 1778
# 2234
# 2690
# 3146
# 3602
# 3723
# 3771
# 3867
# 4055
# 4490
# 4510
# 4966
# 5422
# 5449
# 5640
# 5807
# 5875
# 5998
# 6330
# 6572
# 6785
# 6812
# 7028
# 7239
# 7695
# 8151
# 8607
# 9063
# 9519
# 9975
# 10146
# 10430

# %%
count
# Out:
# 65

# %%
## kaggle 과 데이터 확인 결과 train은 한달에 1일부터 19일까지 존재 test는 한달에 20일 부터 존재
## 여기에 각 값들의 결측값가 추가적으로 존재
train_copy[0::19*24]
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 456   2011-02-02 02:00:00       1        0           1        3   9.02
# 912   2011-03-02 11:00:00       1        0           1        1  13.94
# 1368  2011-04-02 21:00:00       2        0           0        1  13.12
# 1824  2011-05-02 22:00:00       2        0           1        2  24.60
# 2280  2011-06-02 22:00:00       2        0           1        1  26.24
# 2736  2011-07-02 22:00:00       3        0           0        1  29.52
# 3192  2011-08-02 22:00:00       3        0           1        2  31.98
# 3648  2011-09-02 22:00:00       3        0           1        2  26.24
# 4104  2011-10-03 01:00:00       4        0           1        1  14.76
# 4560  2011-11-03 02:00:00       4        0           1        1  13.94
# 5016  2011-12-03 02:00:00       4        0           0        1  10.66
# 5472  2012-01-03 03:00:00       1        0           1        1   6.56
# 5928  2012-02-03 05:00:00       1        0           1        1  10.66
# 6384  2012-03-03 06:00:00       1        0           0        2  14.76
# 6840  2012-04-03 08:00:00       2        0           1        1  13.94
# 7296  2012-05-03 09:00:00       2        0           1        2  19.68
# 7752  2012-06-03 09:00:00       2        0           0        1  24.60
# 8208  2012-07-03 09:00:00       3        0           1        1  32.80
# 8664  2012-08-03 09:00:00       3        0           1        2  30.34
# 9120  2012-09-03 09:00:00       3        1           0        2  28.70
# 9576  2012-10-03 09:00:00       4        0           1        2  25.42
# 10032 2012-11-03 09:00:00       4        0           0        2  13.94
# 10488 2012-12-03 10:00:00       4        0           1        1  18.04
#
#         atemp  humidity  windspeed  casual  registered  count
# 0      14.395        81     0.0000       3          13     16
# 456    11.365        93     8.9981       4           0      4
# 912    15.150        53    22.0028       8          65     73
# 1368   15.150        61    16.9979      24          53     77
# 1824   29.545        73     0.0000      28          97    125
# 2280   31.060        33    16.9979      14         141    155
# 2736   33.335        51    11.0014      78         123    201
# 3192   37.120        59    11.0014      22         169    191
# 3648   30.305        73    11.0014      33         114    147
# 4104   18.180        81     6.0032       1           5      6
# 4560   16.665        76     8.9981       2           5      7
# 5016   12.880        65    11.0014       9          41     50
# 5472    6.820        55    19.0012       0           2      2
# 5928   12.880        60    15.0013       0          17     17
# 6384   18.180        93     6.0032       1           6      7
# 6840   18.180        57     0.0000      27         577    604
# 7296   23.485        88     7.0015      25         279    304
# 7752   31.060        46    12.9980      70         230    300
# 8208   37.120        49    11.0014      46         226    272
# 8664   34.850        66     7.0015      69         327    396
# 9120   33.335        84     8.9981      71         158    229
# 9576   28.790        83    12.9980      30         332    362
# 10032  15.150        49    19.9995      31         188    219
# 10488  21.970        77     8.9981      31         105    136

# %%
## train과 test를 합쳐 하나의 df로 만들어 전체 날자에 대해 결측값 처리 후 다시 분할(한울님 아이디어)
data_set = pd.concat((train_copy,test_copy),axis=0)

# %%
data_set.sort_values('datetime',inplace = True)

# %%
data_set.iloc[0::19*24]
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
#
# 3000   31.820        83    12.9980    48.0       136.0  184.0
# 3168   32.575        70     6.0032    21.0       116.0  137.0
# 1870   33.335        74    12.9980     NaN         NaN    NaN
# 3805   33.335        79     6.0032    14.0       108.0  122.0
# 2329   34.090        62    16.9979     NaN         NaN    NaN
# 4453   27.275        49    12.9980    44.0       122.0  166.0
# 4621   20.455        37    12.9980   141.0       202.0  343.0
# 2786   24.240        31    16.9979     NaN         NaN    NaN
# 5270   19.695        37    16.9979    13.0       194.0  207.0
# 5441   21.210        67    26.0027    20.0        85.0  105.0
# 3245    9.850        37    15.0013     NaN         NaN    NaN
# 6065   12.120        87    11.0014     3.0        57.0   60.0
# 3702   19.695        62    11.0014     NaN         NaN    NaN
# 6740   21.970        88     8.9981     3.0        15.0   18.0
# 6908   15.910        49    16.9979     2.0         3.0    5.0
# 4161   18.180        66     0.0000     NaN         NaN    NaN
# 7556   25.760        77    11.0014     1.0        25.0   26.0
# 7724   24.240        72    12.9980     1.0        11.0   12.0
# 4617   33.335        84     7.0015     NaN         NaN    NaN
# 8372   30.305        83     8.9981     3.0        39.0   42.0
# 5073   29.545        78    12.9980     NaN         NaN    NaN
# 8996   12.120        73     7.0015     2.0        34.0   36.0
# 9164   33.335        79    19.9995     1.0        39.0   40.0
# 5529   22.725        63     0.0000     NaN         NaN    NaN
# 9812   14.395        61    12.9980     0.0        11.0   11.0
# 10016  19.695        40    22.0028    57.0       581.0  638.0
# 5986   21.210        38     7.0015     NaN         NaN    NaN
# 10665  25.000        77    19.0012    18.0       409.0  427.0
# 6442   12.120        56    32.9975     NaN         NaN    NaN

# %%
data_set.reset_index(drop=True, inplace =True)

# %%
## solution_1(성훈님 아이디어)
## for loop (모든 데이터)
## 0 datetime이 1 hour가 차이나지 않는 곳의 인덱스를 추출
## 추출한 인덱스를 기준으로 두 개의 배열로 분할
## 분할한 배열에 한칸을 추가하고 다시 두개의 배열 stack
## datetime 값에는 1 hour를 추가한 datetime 값 입력 

for i in range(len(data_set))[1:]:
    if data_set['datetime'][i] - datetime.timedelta(hours=1) != data_set['datetime'][i-1]:
        print(i)
        a= data_set.iloc[:i,:]
        b = data_set.iloc[i:,:]
        a.append([])
        a['datetime'].iloc[-1] = a['datetime'].iloc[-2]+datetime.timedelta(hours=1)
        
        data_set = pd.concat((a,b))
# Out:
# 29
# 49
# 72
# 95
# 118
# 141
# 236
# 258
# 305
# 396
# 411
# 484
# 506
# 527
# 551
# 574
# 587
# 599
# 623
# 647
# 692
# 739
# 762
# 881
# 903
# 926
# 974
# 1019
# 1041
# 1139
# 1181
# 1203
# 1226
# 1249
# 1297
# 1317
# 1318
# 1462
# 1482
# 1554
# 1577
# 1622
# 1647
# 1669
# 1691
# 1740
# 1811
# 1858
# 1954
# 1976
# 2310
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# 5636
# 5846
# 5894
# 5990
# 6877
# 7835
# 8484
# 8506
# 8554
# 8672
# 8863
# 9030
# 9509
# 9845
# 9867
# 10059
# 10320
# 10848
# 11064
# 15884
# 16090
# 16593
# 17193
# 17215

# %%
data_set.head(50)
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 5  2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 6  2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 7  2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 8  2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 9  2011-01-01 09:00:00       1        0           0        1  13.12  17.425
# 14        72    19.0012    35.0        71.0  106.0
# 15        77    19.9995    40.0        70.0  110.0
# 16        82    19.9995    41.0        52.0   93.0
# 17        82    19.0012    15.0        52.0   67.0
# 18        88    16.9979     9.0        26.0   35.0
# 19        88    16.9979     6.0        31.0   37.0
# 20        87    16.9979    11.0        25.0   36.0
# 21        87    12.9980     3.0        31.0   34.0
# 22        94    15.0013    11.0        17.0   28.0
# 23        88    19.9995    15.0        24.0   39.0
# 24        88    19.9995     4.0        13.0   17.0
# 25        94    16.9979     1.0        16.0   17.0
# 26       100    19.0012     1.0         8.0    9.0
# 27        94    12.9980     2.0         4.0    6.0
# 28        94    12.9980     2.0         1.0    3.0
# 29        77    19.9995     0.0         2.0    2.0
# 30        76    12.9980     0.0         1.0    1.0
# 31        71    15.0013     0.0         8.0    8.0
# 32        76    15.0013     1.0        19.0   20.0
# 33        81    15.0013     7.0        46.0   53.0
# 34        71    16.9979    16.0        54.0   70.0
# 35        66    19.9995    20.0        73.0   93.0
# 36        66     8.9981    11.0        64.0   75.0
# 37        76    12.9980     4.0        55.0   59.0
# 38        81    11.0014    19.0        55.0   74.0
# 39        71    11.0014     9.0        67.0   76.0
# 40        57    12.9980     7.0        58.0   65.0
# 41        46    22.0028    10.0        43.0   53.0
# 42        42    30.0026     1.0        29.0   30.0
# 43        39    23.9994     5.0        17.0   22.0
# 44        44    22.0028    11.0        20.0   31.0
# 45        44    19.9995     0.0         9.0    9.0
# 46        47    11.0014     0.0         8.0    8.0
# 47        44    23.9994     0.0         5.0    5.0
# 48        44    27.9993     0.0         2.0    2.0
# 49        47    26.0027     0.0         1.0    1.0

# %%
## solution_2
## 정적 할당
## start date와 end date간의 차이를 구해 빈 배열 생성 shape = (len(data_set),1)
## datetime 데이터 생성후 할당
## 기존 데이터의 datetime과 dummy배열의 datetime 비교후 같으면 각 데이터 값 삽입(pd.merge 사용)

start_date = data_set['datetime'].iloc[0]
end_date = data_set['datetime'].iloc[-1]

print(start_date,end_date)

dummy_size = (end_date - start_date)/datetime.timedelta(hours=1)
print(dummy_size)
# Out:
# 2011-01-01 00:00:00 2012-12-31 23:00:00
# 17543.0

# %%
dummy_array = pd.DataFrame(np.zeros(int(dummy_size)).reshape(int(dummy_size),-1))

# %%
dummy_array.columns = ['datetime']

# %%
dummy_array['datetime'] = [start_date+datetime.timedelta(hours = x) for x in range(len(dummy_array))]

# %%
dummy_array
# Out:
#                  datetime
# 0     2011-01-01 00:00:00
# 1     2011-01-01 01:00:00
# 2     2011-01-01 02:00:00
# 3     2011-01-01 03:00:00
# 4     2011-01-01 04:00:00
# ...                   ...
# 17538 2012-12-31 18:00:00
# 17539 2012-12-31 19:00:00
# 17540 2012-12-31 20:00:00
# 17541 2012-12-31 21:00:00
# 17542 2012-12-31 22:00:00
#
# [17543 rows x 1 columns]

# %%
data_set
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
#
# 42      46.0    22.0028    10.0        43.0   53.0
# 43      42.0    30.0026     1.0        29.0   30.0
# 44      39.0    23.9994     5.0        17.0   22.0
# 45      44.0    22.0028    11.0        20.0   31.0
# 46      44.0    19.9995     0.0         9.0    9.0
# 47      47.0    11.0014     0.0         8.0    8.0
# 48      44.0    23.9994     0.0         5.0    5.0
# 49      44.0    27.9993     0.0         2.0    2.0

# %%
data_set2 = data_set2.fillna(method = 'ffill')

# %%
## data_set split to train, test
## 날짜 데이터에서 몇일인지 추출해서 column화
## loc 을 이용해서 19일 기준을 train test split
data_set2['day'] = data_set2['datetime'].dt.day

# %%
data_set2['day']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 17538    31
# 17539    31
# 17540    31
# 17541    31
# 17542    31
# Name: day, Length: 17543, dtype: int64

# %%
train_set2 = data_set2.loc[data_set2['day']<20,:]
test_set2 = data_set2.loc[data_set2['day']>=20,:]

# %%
train_set2.iloc[0::19*24]
# Out:
#         datetime  season  holiday  workingday  weather   temp   atemp  \
# 0     2011-01-01     1.0      0.0         0.0      1.0   9.84  14.395
# 744   2011-02-01     1.0      0.0         1.0      2.0   6.56   9.090
# 1416  2011-03-01     1.0      0.0         1.0      1.0  12.30  13.635
# 2160  2011-04-01     2.0      0.0         1.0      3.0  10.66  12.880
# 2880  2011-05-01     2.0      0.0         0.0      1.0  17.22  21.210
# 3624  2011-06-01     2.0      0.0         1.0      1.0  28.70  33.335
# 4344  2011-07-01     3.0      0.0         1.0      1.0  27.06  31.060
# 5088  2011-08-01     3.0      0.0         1.0      1.0  29.52  34.090
# 5832  2011-09-01     3.0      0.0         1.0      1.0  24.60  28.790
# 6552  2011-10-01     4.0      0.0         0.0      1.0  20.50  24.240
# 7296  2011-11-01     4.0      0.0         1.0      2.0  14.76  17.425
# 8016  2011-12-01     4.0      0.0         1.0      1.0  11.48  12.880
# 8760  2012-01-01     1.0      0.0         0.0      1.0  14.76  18.940
# 9504  2012-02-01     1.0      0.0         1.0      1.0  18.04  21.970
# 10200 2012-03-01     1.0      0.0         1.0      2.0  17.22  21.210
# 10944 2012-04-01     2.0      0.0         0.0      2.0  14.76  16.665
# 11664 2012-05-01     2.0      0.0         1.0      2.0  20.50  24.240
# 12408 2012-06-01     2.0      0.0         1.0      1.0  27.06  31.060
# 13128 2012-07-01     3.0      0.0         0.0      1.0  31.16  36.365
# 13872 2012-08-01     3.0      0.0         1.0      1.0  27.88  31.820
# 14616 2012-09-01     3.0      0.0         0.0      1.0  30.34  34.090
# 15336 2012-10-01     4.0      0.0         1.0      1.0  18.86  22.725
# 16080 2012-11-01     4.0      0.0         1.0      1.0  14.76  18.180
# 16800 2012-12-01     4.0      0.0         0.0      1.0  10.66  15.150
#
#        humidity  windspeed  casual  registered  count  day
# 0          81.0     0.0000     3.0        13.0   16.0    1
# 744        64.0     7.0015     2.0         6.0    8.0    1
# 1416       70.0    31.0009     0.0         7.0    7.0    1
# 2160      100.0    11.0014     0.0         6.0    6.0    1
# 2880       67.0     6.0032    19.0        77.0   96.0    1
# 3624       79.0    11.0014     9.0        25.0   34.0    1
# 4344       50.0     0.0000    20.0        48.0   68.0    1
# 5088       70.0    15.0013     7.0        22.0   29.0    1
# 5832       78.0     7.0015    18.0        33.0   51.0    1
# 6552       63.0    26.0027    24.0       106.0  130.0    1
# 7296       87.0    11.0014     3.0        18.0   21.0    1
# 8016       52.0    22.0028     1.0        19.0   20.0    1
# 8760       66.0     0.0000     5.0        43.0   48.0    1
# 9504       38.0    19.0012     0.0        31.0   31.0    1
# 10200      94.0     0.0000     1.0        10.0   11.0    1
# 10944      76.0    16.9979     8.0        59.0   67.0    1
# 11664      59.0    12.9980     7.0        28.0   35.0    1
# 12408      50.0    16.9979    10.0        76.0   86.0    1
# 13128      66.0     0.0000    27.0       122.0  149.0    1
# 13872      79.0    11.0014     3.0        44.0   47.0    1
# 14616      62.0     7.0015    22.0       146.0  168.0    1
# 15336      72.0     7.0015     6.0        39.0   45.0    1
# 16080      57.0     6.0032     8.0        52.0   60.0    1
# 16800      81.0     0.0000     9.0        99.0  108.0    1

# %%
train_set2.reset_index(drop=True,inplace=True)
test_set2.reset_index(drop=True,inplace=True)

# %%
train_set2.drop(columns=['day'],inplace=True)
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
test_set2.drop(columns=['day'],inplace=True)

# %% [markdown]
# ### Step 3. 데이터 생성
#
# 데이터의 세부 정보를 확인하면 holiday와 workingday가 아래와 같이 서술되어있습니다.
#
# holiday; whether the day is considered a holiday
#
# workingday; whether the day is neither a weekend nor holiday
#
# 정작 그런데 정작 weekend 데이터 컬럼은 없군요?
#
# 이게 없어도 되는지, 혹은 있어야 좋을지 토론을 해본 후 필요하다고 생각되면 weekend 컬럼을 생성해주세요. 만일 필요가 없다면 생략해도 됩니다.
#
# 혹은 기타 다른 데이터를 생성하고 싶다면 이번 step에서 생성해주세요.

# %% [markdown]
# # 자전거 렌트 Count 예측하기
#
# ## 프로젝트 목적 : 자전거의 수요를 예측하여 자전거의 수 등 수요 대응형 서비스 구축
#
# ### 가정
#     1. 자전거 렌트는 출퇴근 시간에 증가할 것이다
#     2. 자전거 렌트는 주중보단 주말에 증가할 것이다
#     3. 자전거 렌트는 습도가 높으면 감소할 것이다
#     4. 자전거 렌트는 바람이 많이 불면 감소할 것이다
#     5. 자전거 렌트는 여름, 겨울보다는 봄, 가을에 증가할 것이다
#     6. 자전거 렌트는 특정 휴일에 증가할 것이다(어린이날, 발렌타인 데이, 화이트 데이)

# %%
train_set2['tem_diff'] = train_set2.atemp-train_set2.temp
test_set2['tem_diff'] =  test_set2.atemp-test_set2.temp
# Out:
# /tmp/ipykernel_41/2512606214.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_set2['tem_diff'] = train_set2.atemp-train_set2.temp
# /tmp/ipykernel_41/2512606214.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_set2['tem_diff'] =  test_set2.atemp-test_set2.temp

# %%
# <YOUR CODE>

train_set2['weekend'] = [0 if x <5 else 1 for x in train_set2['datetime'].dt.weekday]
test_set2['weekend'] = [0 if x <5 else 1 for x in test_set2['datetime'].dt.weekday]
# Out:
# /tmp/ipykernel_41/1788884657.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_
60.0    11.0014     4.0        84.0   88.0        0     2.220
# 6596      60.0    11.0014     4.0        84.0   88.0        0     2.220
# 6597      60.0    11.0014     4.0        84.0   88.0        0     2.220
# 6598      56.0     8.9981     4.0        84.0   88.0        0     2.975
#
# [6599 rows x 14 columns]

# %% [markdown]
# ### 가정 1 자전거 렌트는 출퇴근 시간에 증가할 것이다
# * workingday X
# * 07~10, 17~20

# %%
train_set3 = train_set2.copy()
test_set3 = test_set2.copy()

# %%
train_set3['hour'] = train_set3['datetime'].dt.time
test_set3['hour'] = test_set3['datetime'].dt.time

# %%
train_set3.groupby(['hour'])['count'].mean()
# Out:
# hour
# 00:00:00     55.026316
# 01:00:00     33.736842
# 02:00:00     22.756579
# 03:00:00     11.355263
# 04:00:00      6.278509
# 05:00:00     19.620614
# 06:00:00     76.100877
# 07:00:00    212.657895
# 08:00:00    361.982456
# 09:00:00    221.302632
# 10:00:00    174.717105
# 11:00:00    210.221491
# 12:00:00    256.508772
# 13:00:00    257.787281
# 14:00:00    243.442982
# 15:00:00    254.298246
# 16:00:00    316.372807
# 17:00:00    468.765351
# 18:00:00    430.859649
# 19:00:00    315.278509
# 20:00:00    228.517544
# 21:00:00    173.370614
# 22:00:00    133.576754
# 23:00:00     89.508772
# Name: count, dtype: float64

# %%
plt.plot(list(range(0,24)),train_set3.groupby(['hour'])['count'].mean() )

# %% [markdown]
# ### 가정1 확인
# 1. datetime에서 time만 추출하여 입력

# %% [markdown]
# ### 가정 2. 자전거 렌트는 주중보단 주말에 증가할 것이다

# %%
train_set3.groupby(['workingday'])['count'].mean()
# Out:
# workingday
# 0.0    187.579897
# 1.0    191.993425
# Name: count, dtype: float64

# %% [markdown]
# ### 가정2 기각
# 1. 현재 데이터 형태로 유지해도 상관 없음`

# %% [markdown]
# ### 가정 3 자전거 렌트는 습도가 높으면 감소할 것이다

# %%
plt.plot(train_set3.groupby(['humidity'])['count'].mean())

# %%
train_set3.sort_values('humidity').head(50)
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 1151  2011-03-10 23:00:00     1.0      0.0         1.0      3.0  13.94
# 1141  2011-03-10 13:00:00     1.0      0.0         1.0      3.0  17.22
# 1130  2011-03-10 02:00:00     1.0      0.0         1.0      3.0  13.94
# 1131  2011-03-10 03:00:00     1.0      0.0         1.0      3.0  13.94
# 1132  2011-03-10 04:00:00     1.0      0.0         1.0      3.0  13.94
# 1145  2011-03-10 17:00:00     1.0      0.0         1.0      2.0  18.04
# 1144  2011-03-10 16:00:00     1.0      0.0         1.0      3.0  17.22
# 1143  2011-03-10 15:00:00     1.0      0.0         1.0      3.0  18.04
# 1142  2011-03-10 14:00:00     1.0      0.0         1.0      3.0  18.04
# 1133  2011-03-10 05:00:00     1.0      0.0         1.0      3.0  14.76
# 1134  2011-03-10 06:00:00     1.0      0.0         1.0      3.0  14.76
# 1135  2011-03-10 07:00:00     1.0      0.0         1.0      3.0  15.58
# 1136  2011-03-10 08:00:00     1.0      0.0         1.0      3.0  15.58
# 1137  2011-03-10 09:00:00     1.0      0.0         1.0      3.0  16.40
# 1130      1.970  02:00:00
# 1131      1.970  03:00:00
# 1132      1.970  04:00:00
# 1145      3.930  17:00:00
# 1144      3.990  16:00:00
# 1143      3.930  15:00:00
# 1142      3.930  14:00:00
# 1133      2.665  05:00:00
# 1134      1.905  06:00:00
# 1135      4.115  07:00:00
# 1136      4.115  08:00:00
# 1137      4.055  09:00:00
# 1138      4.055  10:00:00
# 1139      4.055  11:00:00
# 1146      3.930  18:00:00
# 1129      1.970  01:00:00
# 1140      3.990  12:00:00
# 1149      2.665  21:00:00
# 1128      1.970  00:00:00
# 1147      3.930  19:00:00
# 1148      1.905  20:00:00
# 1150      2.725  22:00:00
# 887       3.680  23:00:00
# 886       3.620  22:00:00
# 888       3.805  00:00:00
# 890       3.930  02:00:00
# 889       3.865  01:00:00
# 891       3.990  03:00:00
# 782       4.945  14:00:00
# 902       3.865  14:00:00
# 893       4.055  05:00:00
# 892       4.055  04:00:00
# 903       3.930  15:00:00
# 901       3.930  13:00:00
# 7003      3.620  19:00:00
# 899       3.930  11:00:00
# 898       3.990  10:00:00
# 10216     3.990  16:00:00
# 897       4.055  09:00:00
# 904       3.930  16:00:00
# 7023      4.885  15:00:00
# 2752      1.230  16:00:00
# 6905      4.885  17:00:00
# 895       4.115  07:00:00
# 896       4.115  08:00:00
# 894       4.055  06:00:00
# 10214     3.930  14:00:00
# 1095      4.180  15:00:00

# %% [markdown]
# ### 가정 3 판단 보류

# %% [markdown]
# ### 가정 4. 자전거 렌트는 바람이 많이 불면 감소할 것이다

# %%
plt.plot(train_set3.groupby(['windspeed'])['count'].mean())

# %% [markdown]
# ### 가정 4  상관성을 확인하기 어렵다

# %% [markdown]
# ### 가정 5. 자전거 렌트는 여름, 겨울보다는 봄, 가을에 증가할 것이다

# %%
# 계절 별 자전거 이용수 histgram
train_set3.groupby(['season'])['count'].mean()
# Out:
# season
# 1.0    114.306652
# 2.0    215.021199
# 3.0    234.165205
# 4.0    198.847588
# Name: count, dtype: float64

# %%
fig,axes = plt.subplots(2,2,figsize=(20,10))

for i in range(4):
    axes[i%2,i//2].scatter(train_set3.loc[train_set3['season']==i+1,'humidity'],train_set3.loc[train_set3['season']==i+1,'count'])
    axes[i%2,i//2].set_ylim([0,1000])

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.gca(projection = '3d')
ax1.scatter(train_set3['season'],train_set3['humidity'],train_set3['count'])
ax1.view_init(20, 80)
# Out:
# /tmp/ipykernel_41/2613597201.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax1 = fig.gca(projection = '3d')

# %% [markdown]
# ### 가정 5 기각
# * 데이터 지역인 워싱턴의 계절적 특성이 다름

# %% [markdown]
# ### Step 4. 시각화를 통한 EDA
#
# 본 풀잎에서는 다루지 않았지만(노드에서는 등장) binning 역시 DS에서 상당히 많이 사용되는 스킬 중 하나입니다. 아래 링크를 통해서 binning의 역할에 대해서 함께 살펴봅시다.
#
# [링크](https://m.blog.naver.com/gksshdk8003/221517070898)

# %%
train_set3.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count',
#        'weekend', 'tem_diff', 'hour'],
#       dtype='object')

# %%
plt.hist(train_set3['windspeed'])
# Out:
# (array([1.317e+03, 4.104e+03, 2.839e+03, 1.555e+03, 7.000e+02, 2.810e+02,
#         1.070e+02, 3.100e+01, 7.000e+00, 3.000e+00]),
#  array([ 0.     ,  5.69969, 11.39938, 17.09907, 22.79876, 28.49845,
#         34.19814, 39.89783, 45.59752, 51.29721, 56.9969 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(train_set3['windspeed'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fda12a62370>,
#   <matplotlib.lines.Line2D at 0x7fda12a62700>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fda12a62a90>,
#   <matplotlib.lines.Line2D at 0x7fda12a62e20>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fda12a84fa0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fda12a961f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fda12a96580>],
#  'means': []}

# %%
corr = train_set3.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_03ab2_row0_col0, #T_03ab2_row1_col1, #T_03ab2_row2_col2, #T_03ab2_row3_col3, #T_03ab2_row4_col4, #T_03ab2_row5_col5, #T_03ab2_row6_col6, #T_03ab2_row7_col7, #T_03ab2_row8_col8, #T_03ab2_row9_col9, #T_03ab2_row10_col10, #T_03ab2_row11_col11, #T_03ab2_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_03ab2_row0_col1 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_03ab2_row0_col2, #T_03ab2_row6_col3, #T_03ab2_row10_col11 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_03ab2_row0_col3, #T_03ab2_row2_col0, #T_03ab2_row11_col9 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_03ab2_row0_col4, #T_03ab2_row8_col7, #T_03ab2_row9_col7 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_03ab2_row0_col5, #T_03ab2_row10_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_03ab2_row0_col6 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_03ab2_row0_col7, #T_03ab2_row1_col3, #T_03ab2_row11_col0 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_03ab2_row0_col8 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_03ab2_row0_col9 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_03ab2_row0_col10 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_03ab2_row0_col11 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_03ab2_row0_col12, #T_03ab2_row10_col12, #T_03ab2_row12_col9 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_03ab2_row1_col0, #T_03ab2_row2_col3 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_03ab2_row1_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_03ab2_row1_col4 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_03ab2_row1_col5, #T_03ab2_row11_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_03ab2_row1_col6, #T_03ab2_row11_col6 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_03ab2_row1_col7, #T_03ab2_row6_col12 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_03ab2_row1_col8 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_03ab2_row1_col9, #T_03ab2_row5_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_03ab2_row1_col10, #T_03ab2_row8_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_03ab2_row1_col11, #T_03ab2_row9_col11 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_03ab2_row1_col12 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_03ab2_row2_col1, #T_03ab2_row2_col11, #T_03ab2_row3_col5, #T_03ab2_row6_col4, #T_03ab2_row6_col7, #T_03ab2_row6_col8, #T_03ab2_row6_col9, #T_03ab2_row6_col10, #T_03ab2_row7_col0, #T_03ab2_row7_col5, #T_03ab2_row7_col12, #T_03ab2_row8_col3, #T_03ab2_row8_col6, #T_03ab2_row11_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_03ab2_row2_col4, #T_03ab2_row11_col3, #T_03ab2_row12_col3 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_03ab2_row2_col5 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_03ab2_row2_col6, #T_03ab2_row2_col7, #T_03ab2_row2_col10, #T_03ab2_row3_col7 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_03ab2_row2_col8, #T_03ab2_row7_col6, #T_03ab2_row9_col3, #T_03ab2_row10_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_03ab2_row2_col9 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_03ab2_row2_col12 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_03ab2_row3_col0, #T_03ab2_row7_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_03ab2_row3_col1, #T_03ab2_row4_col6, #T_03ab2_row6_col1, #T_03ab2_row11_col12 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_03ab2_row3_col2, #T_03ab2_row4_col2, #T_03ab2_row12_col11 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_03ab2_row3_col4, #T_03ab2_row10_col3 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_03ab2_row3_col6 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_03ab2_row3_col8 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_03ab2_row3_col9 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_03ab2_row3_col10 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_03ab2_row3_col11, #T_03ab2_row5_col9 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_03ab2_row3_col12 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_03ab2_row4_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_03ab2_row4_col1, #T_03ab2_row10_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_03ab2_row4_col3, #T_03ab2_row5_col3, #T_03ab2_row12_col7 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_03ab2_row4_col5, #T_03ab2_row5_col4 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_03ab2_row4_col7, #T_03ab2_row5_col6 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_03ab2_row4_col8 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_03ab2_row4_col9, #T_03ab2_row4_col11 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_03ab2_row4_col10, #T_03ab2_row9_col2 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_03ab2_row4_col12, #T_03ab2_row6_col2, #T_03ab2_row7_col11, #T_03ab2_row12_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_03ab2_row5_col0, #T_03ab2_row9_col4 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_03ab2_row5_col2, #T_03ab2_row8_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_03ab2_row5_col7 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_03ab2_row5_col8, #T_03ab2_row5_col12, #T_03ab2_row8_col9 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_03ab2_row5_col10, #T_03ab2_row12_col5 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_03ab2_row5_col11 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_03ab2_row6_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_03ab2_row6_col5 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_03ab2_row6_col11 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_03ab2_row7_col1 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_03ab2_row7_col2, #T_03ab2_row10_col2, #T_03ab2_row11_col8 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_03ab2_row7_col4 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_03ab2_row7_col8 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_03ab2_row7_col9 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_03ab2_row7_col10, #T_03ab2_row8_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_03ab2_row8_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_03ab2_row8_col4 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_03ab2_row8_col10 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_03ab2_row8_col11 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_03ab2_row8_col12 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_03ab2_row9_col0, #T_03ab2_row10_col0 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_03ab2_row9_col1 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_03ab2_row9_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_03ab2_row9_col6 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_03ab2_row9_col8 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_03ab2_row9_col10, #T_03ab2_row10_col9 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_03ab2_row9_col12 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_03ab2_row10_col4 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_03ab2_row10_col5 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_03ab2_row10_col8 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_03ab2_row11_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_03ab2_row11_col4 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_03ab2_row11_col7 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_03ab2_row11_col10 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_03ab2_row12_col0 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_03ab2_row12_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_03ab2_row12_col4 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_03ab2_row12_col6 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_03ab2_row12_col8 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_03ab2_row12_col10 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# </style>
# <table id

# %%
corr = train_set3[['temp','atemp','humidity','windspeed','count']].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_23cf9_row0_col0, #T_23cf9_row1_col1, #T_23cf9_row2_col2, #T_23cf9_row3_col3, #T_23cf9_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_23cf9_row0_col1, #T_23cf9_row1_col0 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_23cf9_row0_col2 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_23cf9_row0_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_23cf9_row0_col4 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_23cf9_row1_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_23cf9_row1_col3 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_23cf9_row1_col4 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_23cf9_row2_col0, #T_23cf9_row2_col3, #T_23cf9_row2_col4, #T_23cf9_row3_col1, #T_23cf9_row3_col2, #T_23cf9_row4_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_23cf9_row2_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_23cf9_row3_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_23cf9_row3_col4 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_23cf9_row4_col0 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_23cf9_row4_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_23cf9_row4_col3 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# </style>
# <table id="T_23cf9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >temp</th>
#       <th class="col_heading level0 col1" >atemp</th>
#       <th class="col_heading level0 col2" >humidity</th>
#       <th class="col_heading level0 col3" >windspeed</th>
#       <th class="col_heading level0 col4" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23cf9_level0_row0" class="row_heading level0 row0" >temp</th>
#       <td id="T_23cf9_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_23cf9_row0_col1" class="data row0 col1" >0.985059</td>
#       <td id="T_23cf9_row0_col2" class="data row0 col2" >-0.066810</td>
#       <td id="T_23cf9_row0_col3" class="data row0 col3" >-0.018568</td>
#       <td id="T_23cf9_row0_col4" class="data row0 col4" >0.398225</td>
#     </tr>
#     <tr>
#       <th id="T_23cf9_level0_row1" class="row_heading level0 row1" >atemp</th>
#       <td id="T_23cf9_row1_col0" class="data row1 col0" >0.985059</td>
#       <td id="T_23cf9_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_23cf9_row1_col2" class="data row1 col2" >-0.045731</td>
#       <td id="T_23cf9_row1_col3" class="data row1 col3" >-0.058452</td>
#       <td id="T_23cf9_row1_col4" class="data row1 col4" >0.393727</td>
#     </tr>
#     <tr>
#       <th id="T_23cf9_level0_row2" class="row_heading level0 row2" >humidity</th>
#       <td id="T_23cf9_row2_col0" class="data row2 col0" >-0.066810</td>
#       <td id="T_23cf9_row2_col1" class="data row2 col1" >-0.045731</td>
#       <td id="T_23cf9_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_23cf9_row2_col3" class="data row2 col3" >-0.316662</td>
#       <td id="T_23cf9_row2_col4" class="data row2 col4" >-0.317617</td>
#     </tr>
#     <tr>
#       <th id="T_23cf9_level0_row3" class="row_heading level0 row3" >windspeed</th>
#       <td id="T_23cf9_row3_col0" class="data row3 col0" >-0.018568</td>
#       <td id="T_23cf9_row3_col1" class="data row3 col1" >-0.058452</td>
#       <td id="T_23cf9_row3_col2" class="data row3 col2" >-0.316662</td>
#       <td id="T_23cf9_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_23cf9_row3_col4" class="data row3 col4" >0.099933</td>
#     </tr>
#     <tr>
#       <th id="T_23cf9_level0_row4" class="row_heading level0 row4" >count</th>
#       <td id="T_23cf9_row4_col0" class="data row4 col0" >0.398225</td>
#       <td id="T_23cf9_row4_col1" class="data row4 col1" >0.393727</td>
#       <td id="T_23cf9_row4_col2" class="data row4 col2" >-0.317617</td>
#       <td id="T_23cf9_row4_col3" class="data row4 col3" >0.099933</td>
#       <td id="T_23cf9_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
#  Step 4는 다시 돌아올 예정입니다. 아래 두가지 과제를 한 뒤 넘어가기 바랍니다. 다시 돌아왔다면 원하는 대로 시각화와 EDA를 진행해보시기 바랍니다.
#
#  1. datetime을 원하는대로 binning하고(새벽,오전,오후,밤 / 일일 / 주 등...) binning의 효과를 잘 보여줄 수 있는 그래프를 선택해 그려주세요.

# %%
# <YOUR CODE>

# %% [markdown]
#   2. temp, humidity, windspeed를 각각 축으로 삼는 산점도(혹은 저 중 두개를 두 축으로 삼는 산점도)를 그리고 표기되는 데이터(점)의 크기는 count의 크기를 반영하도록 만드시오.

# %%
# <YOUR CODE>

# %% [markdown]
# # Step 5. 예측하기
#
# 충분히 EDA가 진행되었다면 bike_sharing_demand_train.csv 에서 적당한 데이터를 선별하여 X로 두고 y는 count 컬럼으로 삼아 예측하고 bike_sharing_demand_test.csv 에 count 컬럼을 생성하여 채워넣어봅시다.

# %% [markdown]
# ### arima
# ### RNN
# ### LSTM
# ### SVM
# ### RF
# ###

# %%
train_set3
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00     1.0      0.0         0.0      1.0   9.84
# 1     2011-01-01 01:00:00     1.0      0.0         0.0      1.0   9.02
# 2     2011-01-01 02:00:00     1.0      0.0         0.0      1.0   9.02
# 3     2011-01-01 03:00:00     1.0      0.0         0.0      1.0   9.84
# 4     2011-01-01 04:00:00     1.0      0.0         0.0      1.0   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 
60.0    11.0014     4.0        84.0   88.0        0     2.220
# 6597      60.0    11.0014     4.0        84.0   88.0        0     2.220
# 6598      56.0     8.9981     4.0        84.0   88.0        0     2.975
#
#           hour
# 0     00:00:00
# 1     01:00:00
# 2     02:00:00
# 3     03:00:00
# 4     04:00:00
# ...        ...
# 6594  18:00:00
# 6595  19:00:00
# 6596  20:00:00
# 6597  21:00:00
# 6598  22:00:00
#
# [6599 rows x 15 columns]

# %%
col = train_set3.columns[1:]

# %%
col.drop(['casual','registered','count'])
# Out:
# Index(['season', 'holiday', 'workingday', 'weather', 'temp', 'atemp',
#        'humidity', 'windspeed', 'weekend', 'tem_diff', 'hour'],
#       dtype='object')

# %%
train_set3['hour']=[int(x[:2]) for x in train_set3['hour'].astype(str)]
test_set3['hour']=[int(x[:2]) for x in test_set3['hour'].astype(str)]

# %%
tra

# %%
x_train = train_set3[col.drop(['casual','registered','count'])]
y_train = train_set3['count']
x_test = train_set3[col.drop(['casual','registered','count'])]
y_test = train_set3['count']

# %%
x_train
# Out:
#        season  holiday  workingday  weather   temp   atemp  humidity  \
# 0         1.0      0.0         0.0      1.0   9.84  14.395      81.0
# 1         1.0      0.0         0.0      1.0   9.02  13.635      80.0
# 2         1.0      0.0         0.0      1.0   9.02  13.635      80.0
# 3         1.0      0.0         0.0      1.0   9.84  14.395      75.0
# 4         1.0      0.0         0.0      1.0   9.84  14.395      75.0
# ...       ...      ...         ...      ...    ...     ...       ...
# 10939     4.0      0.0         1.0      1.0  15.58  19.695      50.0
# 10940     4.0      0.0         1.0      1.0  14.76  17.425      57.0
# 10941     4.0      0.0         1.0      1.0  13.94  15.910      61.0
# 10942     4.0      0.0         1.0      1.0  13.94  17.425      61.0
# 10943     4.0      0.0         1.0      1.0  13.12  16.665      66.0
#
#        windspeed  weekend  tem_diff      hour
# 0         0.0000        1     4.555  00:00:00
# 1         0.0000        1     4.615  01:00:00
# 2         0.0000        1     4.615  02:00:00
# 3         0.0000        1     4.555  03:00:00
# 4         0.0000        1     4.555  04:00:00
# ...          ...      ...       ...       ...
# 10939    26.0027        0     4.115  19:00:00
# 10940    15.0013        0     2.665  20:00:00
# 10941    15.0013        0     1.970  21:00:00
# 10942     6.0032        0     3.485  22:00:00
# 10943     8.9981        0     3.545  23:00:00
#
# [10944 rows x 11 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x_train)
principalDf = pd.DataFrame(data = principalComponents , columns = ['principal component 1', 'principal component 2'])

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['count']
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = principalDf['count'] == target
    ax.scatter(principalDf.loc[indicesToKeep, 'principal component 1']
               , principalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
#ax.legend()
ax.grid()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_41/978296120.py in <module>
#       7 colors = ['r', 'g', 'b']
#       8 for target, color in zip(targets,colors):
# ----> 9     indicesToKeep = principalDf['count'] == target
#      10     ax.scatter(principalDf.loc[indicesToKeep, 'principal component 1']
#      11                , principalDf.loc[indicesToKeep, 'principal component 2']
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'count'

# %% [markdown]
# 어떤 결과가 나왔나요?
#
# Step 4로 돌아가 EDA를 진행하며 찾아낸 적절한 컬럼을 골라 성능을 개선시켜봅시다.

# %% [markdown]
# ### Step 6. (보너스) 성능 개선
#
# 어쩌면 casual와 registered는 각기 다른 요소의 영향을 받을지도 모르겠습니다. casual와 registered를 따로 예측하고 그 합산이 count가 되도록 Step 5를 반복해주세요.
#
# 혹은 [casual, registered, count]라는 벡터를 예측하는 것도 재밌을 겁니다.

# %%
# <YOUR CODE>
