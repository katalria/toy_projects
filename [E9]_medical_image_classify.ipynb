# %% [markdown]
# ## E9 의료 이미지 분석 모델

# %% [markdown]
# ## 00. package import, variable setting

# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings 
from keras.preprocessing.image import ImageDataGenerator
warnings.filterwarnings(action='ignore')

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미합니다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 16
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %% [markdown]
# ## 01. data loas and preprocessing

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/NORMAL2-IM-1317-0001.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person299_bacteria_1418.jpeg

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1070
# Pneumonia images count in training set: 3115

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds_1 = prepare_for_training(train_ds)
val_ds_1 = prepare_for_training(val_ds)

# %% [markdown]
# ## 02. image data visualization

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(4,math.ceil(BATCH_SIZE/4),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds_1))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ## 03. modeling

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# ## 04. data imbalance 처리

# %% [markdown]
# * 데이터의 불균형 문제를 해결하기 위해 사용
# * classification의 특정 label 값의 loss에 더 높은 weigth를 주는 방법

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.96
# Weight for PNEUMONIA: 0.67

# %% [markdown]
# ## 05. model train

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds_1,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds_1,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 61s 187ms/step - loss: 0.3779 - accuracy: 0.8096 - precision: 0.9519 - recall: 0.7838 - val_loss: 0.7010 - val_accuracy: 0.7327 - val_precision: 0.7327 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 49s 187ms/step - loss: 0.2312 - accuracy: 0.9150 - precision: 0.9725 - recall: 0.9115 - val_loss: 1.5126 - val_accuracy: 0.7356 - val_precision: 0.7356 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 49s 188ms/step - loss: 0.1945 - accuracy: 0.9270 - precision: 0.9736 - recall: 0.9269 - val_loss: 0.1835 - val_accuracy: 0.9115 - val_precision: 0.8923 - val_recall: 1.0000
# Epoch 4/25
# 261/261 [==============================] - 49s 190ms/step - loss: 0.1841 - accuracy: 0.9322 - precision: 0.9777 - recall: 0.9302 - val_loss: 0.0661 - val_accuracy: 0.9750 - val_precision: 0.9767 - val_recall: 0.9895
# Epoch 5/25
# 261/261 [==============================] - 53s 205ms/step - loss: 0.1698 - accuracy: 0.9351 - precision: 0.9778 - recall: 0.9341 - val_loss: 0.2786 - val_accuracy: 0.9115 - val_precision: 0.9985 - val_recall: 0.8809
# Epoch 6/25
# 261/261 [==============================] - 55s 213ms/step - loss: 0.1825 - accuracy: 0.9341 - precision: 0.9781 - recall: 0.9326 - val_loss: 0.7251 - val_accuracy: 0.7337 - val_precision: 0.7337 - val_recall: 1.0000
# Epoch 7/25
# 261/261 [==============================] - 47s 181ms/step - loss: 0.1792 - accuracy: 0.9330 - precision: 0.9754 - recall: 0.9332 - val_loss: 0.0866 - val_accuracy: 0.9712 - val_precision: 0.9933 - val_recall: 0.9672
# Epoch 8/25
# 261/261 [==============================] - 47s 182ms/step - loss: 0.1344 - accuracy: 0.9502 - precision: 0.9863 - recall: 0.9463 - val_loss: 0.1009 - val_accuracy: 0.9596 - val_precision: 0.9945 - val_recall: 0.9503
# Epoch 9/25
# 261/261 [==============================] - 46s 176ms/step - loss: 0.1291 - accuracy: 0.9550 - precision: 0.9883 - recall: 0.9508 - val_loss: 0.0598 - val_accuracy: 0.9837 - val_precision: 0.9844 - val_recall: 0.9934
# Epoch 10/25
# 261/261 [==============================] - 48s 184ms/step - loss: 0.1247 - accuracy: 0.9559 - precision: 0.9889 - recall: 0.9512 - val_loss: 1.6339 - val_accuracy: 0.5346 - val_precision: 1.0000 - val_recall: 0.3657
# Epoch 11/25
# 261/261 [==============================] - 46s 178ms/step - loss: 0.1501 - accuracy: 0.9416 - precision: 0.9868 - recall: 0.9342 - val_loss: 0.1912 - val_accuracy: 0.9269 - val_precision: 1.0000 - val_recall: 0.9005
# Epoch 12/25
# 261/261 [==============================] - 49s 190ms/step - loss: 0.1095 - accuracy: 0.9581 - precision: 0.9897 - recall: 0.9537 - val_loss: 0.0953 - val_accuracy: 0.9663 - val_precision: 0.9973 - val_recall: 0.9567
# Epoch 13/25
# 261/261 [==============================] - 47s 179ms/step - loss: 0.1311 - accuracy: 0.9492 - precision: 0.9865 - recall: 0.9446 - val_loss: 0.2780 - val_accuracy: 0.9010 - val_precision: 1.0000 - val_recall: 0.8648
# Epoch 14/25
# 261/261 [==============================] - 48s 182ms/step - loss: 0.1048 - accuracy: 0.9622 - precision: 0.9903 - recall: 0.9584 - val_loss: 0.3519 - val_accuracy: 0.8779 - val_precision: 0.9984 - val_recall: 0.8349
# Epoch 15/25
# 261/261 [==============================] - 48s 185ms/step - loss: 0.0932 - accuracy: 0.9641 - precision: 0.9907 - recall: 0.9609 - val_loss: 0.2706 - val_accuracy: 0.9135 - val_precision: 0.9985 - val_recall: 0.8834
# Epoch 16/25
# 261/261 [==============================] - 47s 182ms/step - loss: 0.1027 - accuracy: 0.9600 - precision: 0.9903 - recall: 0.9555 - val_loss: 0.1133 - val_accuracy: 0.9635 - val_precision: 0.9571 - val_recall: 0.9948
# Epoch 17/25
# 261/261 [==============================] - 47s 180ms/step - loss: 0.0998 - accuracy: 0.9641 - precision: 0.9907 - recall: 0.9608 - val_loss: 0.1675 - val_accuracy: 0.9394 - val_precision: 0.9290 - val_recall: 0.9935
# Epoch 18/25
# 261/261 [==============================] - 47s 180ms/step - loss: 0.1044 - accuracy: 0.9622 - precision: 0.9894 - recall: 0.9597 - val_loss: 0.0971 - val_accuracy: 0.9615 - val_precision: 0.9986 - val_recall: 0.9490
# Epoch 19/25
# 261/261 [==============================] - 47s 180ms/step - loss: 0.0923 - accuracy: 0.9648 - precision: 0.9917 - recall: 0.9607 - val_loss: 0.1037 - val_accuracy: 0.9625 - val_precision: 0.9617 - val_recall: 0.9882
# Epoch 20/25
# 261/261 [==============================] - 48s 185ms/step - loss: 0.1052 - accuracy: 0.9588 - precision: 0.9877 - recall: 0.9564 - val_loss: 0.0622 - val_accuracy: 0.9769 - val_precision: 0.9843 - val_recall: 0.9843
# Epoch 21/25
# 261/261 [==============================] - 46s 177ms/step - loss: 0.0853 - accuracy: 0.9682 - precision: 0.9921 - recall: 0.9650 - val_loss: 0.1260 - val_accuracy: 0.9625 - val_precision: 0.9973 - val_recall: 0.9516
# Epoch 22/25
# 261/261 [==============================] - 46s 177ms/step - loss: 0.0904 - accuracy: 0.9662 - precision: 0.9914 - recall: 0.9628 - val_loss: 0.0749 - val_accuracy: 0.9683 - val_precision: 0.9919 - val_recall: 0.9648
# Epoch 23/25
# 261/261 [==============================] - 47s 182ms/step - loss: 0.0665 - accuracy: 0.9753 - precision: 0.9951 - recall: 0.9719 - val_loss: 0.1547 - val_accuracy: 0.9423 - val_precision: 0.9986 - val_recall: 0.9227
# Epoch 24/25
# 261/261 [==============================] - 47s 180ms/step - loss: 0.0630 - accuracy: 0.9787 - precision: 0.9948 - recall: 0.9765 - val_loss: 0.1442 - val_accuracy: 0.9510 - val_precision: 0.9418 - val_recall: 0.9948
# Epoch 25/25
# 261/261 [==============================] - 48s 185ms/step - loss: 0.0664 - accuracy: 0.9758 - precision: 0.9944 - recall: 0.9729 - val_loss: 0.0670 - val_accuracy: 0.9731 - val_precision: 0.9754 - val_recall: 0.9882

# %% [markdown]
# ## 06. model result

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 5s 119ms/step - loss: 1.3101 - accuracy: 0.7356 - precision: 0.7057 - recall: 0.9897
# Loss: 1.3101171255111694,
# Accuracy: 0.7355769276618958,
# Precision: 0.70566725730896,
# Recall: 0.9897435903549194

# %% [markdown]
# ## 07. model parameter control

# %%
def augment(image,label):
    image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
    return image,label

def prepare_for_training(ds, shuffle_buffer_size=1000):
    # augment 적용 부분이 배치처리 함수에 추가되었습니다.
    ds = ds.map(
            augment,       # augment 함수 적용
            num_parallel_calls=2
        )
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds_2 = prepare_for_training(train_ds)
val_ds_2 = prepare_for_training(val_ds)

# %%
train_ds_2
# Out:
# <PrefetchDataset shapes: ((None, 180, 180, 3), (None,)), types: (tf.float32, tf.bool)>

# %% [markdown]
# * model optimizer : adam >> rmsprop

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='rmsprop',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds_2,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds_2,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 59s 189ms/step - loss: 0.4253 - accuracy: 0.7986 - precision: 0.9444 - recall: 0.7752 - val_loss: 0.7928 - val_accuracy: 0.7346 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 49s 189ms/step - loss: 0.2645 - accuracy: 0.9016 - precision: 0.9674 - recall: 0.8980 - val_loss: 0.9879 - val_accuracy: 0.7337 - val_precision: 0.7337 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 49s 188ms/step - loss: 0.2389 - accuracy: 0.9097 - precision: 0.9665 - recall: 0.9102 - val_loss: 3.6685 - val_accuracy: 0.3317 - val_precision: 1.0000 - val_recall: 0.0891
# Epoch 4/25
# 261/261 [==============================] - 49s 187ms/step - loss: 0.2262 - accuracy: 0.9138 - precision: 0.9700 - recall: 0.9127 - val_loss: 1.4334 - val_accuracy: 0.5885 - val_precision: 1.0000 - val_recall: 0.4398
# Epoch 5/25
# 261/261 [==============================] - 50s 191ms/step - loss: 0.1695 - accuracy: 0.9375 - precision: 0.9768 - recall: 0.9381 - val_loss: 0.5126 - val_accuracy: 0.8154 - val_precision: 0.7987 - val_recall: 1.0000
# Epoch 6/25
# 261/261 [==============================] - 52s 198ms/step - loss: 0.1735 - accuracy: 0.9425 - precision: 0.9765 - recall: 0.9457 - val_loss: 0.1078 - val_accuracy: 0.9606 - val_precision: 0.9932 - val_recall: 0.9528
# Epoch 7/25
# 261/261 [==============================] - 56s 214ms/step - loss: 0.1690 - accuracy: 0.9404 - precision: 0.9792 - recall: 0.9398 - val_loss: 0.1640 - val_accuracy: 0.9385 - val_precision: 0.9972 - val_recall: 0.9186
# Epoch 8/25
# 261/261 [==============================] - 50s 194ms/step - loss: 0.1541 - accuracy: 0.9456 - precision: 0.9806 - recall: 0.9456 - val_loss: 0.2908 - val_accuracy: 0.9135 - val_precision: 1.0000 - val_recall: 0.8819
# Epoch 9/25
# 261/261 [==============================] - 47s 180ms/step - loss: 0.1524 - accuracy: 0.9516 - precision: 0.9821 - recall: 0.9523 - val_loss: 0.7228 - val_accuracy: 0.7856 - val_precision: 0.7818 - val_recall: 0.9817
# Epoch 10/25
# 261/261 [==============================] - 46s 178ms/step - loss: 0.1504 - accuracy: 0.9471 - precision: 0.9807 - recall: 0.9477 - val_loss: 0.0594 - val_accuracy: 0.9817 - val_precision: 0.9934 - val_recall: 0.9816
# Epoch 11/25
# 261/261 [==============================] - 47s 182ms/step - loss: 0.1465 - accuracy: 0.9526 - precision: 0.9814 - recall: 0.9542 - val_loss: 0.0823 - val_accuracy: 0.9644 - val_precision: 0.9932 - val_recall: 0.9582
# Epoch 12/25
# 261/261 [==============================] - 46s 178ms/step - loss: 0.1148 - accuracy: 0.9583 - precision: 0.9855 - recall: 0.9583 - val_loss: 0.0933 - val_accuracy: 0.9663 - val_precision: 0.9973 - val_recall: 0.9568
# Epoch 13/25
# 261/261 [==============================] - 46s 177ms/step - loss: 0.1293 - accuracy: 0.9576 - precision: 0.9858 - recall: 0.9570 - val_loss: 0.0601 - val_accuracy: 0.9817 - val_precision: 0.9947 - val_recall: 0.9804
# Epoch 14/25
# 261/261 [==============================] - 46s 178ms/step - loss: 0.1193 - accuracy: 0.9631 - precision: 0.9858 - recall: 0.9642 - val_loss: 0.2328 - val_accuracy: 0.9279 - val_precision: 0.9914 - val_recall: 0.9094
# Epoch 15/25
# 261/261 [==============================] - 46s 178ms/step - loss: 0.1144 - accuracy: 0.9636 - precision: 0.9878 - recall: 0.9631 - val_loss: 0.0839 - val_accuracy: 0.9692 - val_precision: 0.9973 - val_recall: 0.9607
# Epoch 16/25
# 261/261 [==============================] - 46s 176ms/step - loss: 0.1135 - accuracy: 0.9612 - precision: 0.9874 - recall: 0.9599 - val_loss: 0.4027 - val_accuracy: 0.8808 - val_precision: 0.9790 - val_recall: 0.8558
# Epoch 17/25
# 261/261 [==============================] - 47s 179ms/step - loss: 0.1033 - accuracy: 0.9679 - precision: 0.9889 - recall: 0.9679 - val_loss: 0.0814 - val_accuracy: 0.9731 - val_precision: 0.9694 - val_recall: 0.9948
# Epoch 18/25
# 261/261 [==============================] - 47s 180ms/step - loss: 0.1172 - accuracy: 0.9670 - precision: 0.9875 - recall: 0.9678 - val_loss: 0.0437 - val_accuracy: 0.9827 - val_precision: 0.9960 - val_recall: 0.9803
# Epoch 19/25
# 261/261 [==============================] - 47s 182ms/step - loss: 0.1079 - accuracy: 0.9648 - precision: 0.9885 - recall: 0.9640 - val_loss: 0.0702 - val_accuracy: 0.9721 - val_precision: 0.9842 - val_recall: 0.9777
# Epoch 20/25
# 261/261 [==============================] - 46s 178ms/step - loss: 0.0958 - accuracy: 0.9689 - precision: 0.9901 - recall: 0.9679 - val_loss: 0.0649 - val_accuracy: 0.9779 - val_precision: 0.9987 - val_recall: 0.9711
# Epoch 21/25
# 261/261 [==============================] - 47s 180ms/step - loss: 0.0959 - accuracy: 0.9703 - precision: 0.9888 - recall: 0.9710 - val_loss: 0.0986 - val_accuracy: 0.9673 - val_precision: 0.9959 - val_recall: 0.9594
# Epoch 22/25
# 261/261 [==============================] - 47s 182ms/step - loss: 0.0859 - accuracy: 0.9701 - precision: 0.9904 - recall: 0.9690 - val_loss: 0.0440 - val_accuracy: 0.9846 - val_precision: 0.9844 - val_recall: 0.9948
# Epoch 23/25
# 261/261 [==============================] - 47s 180ms/step - loss: 0.0888 - accuracy: 0.9710 - precision: 0.9895 - recall: 0.9714 - val_loss: 0.0908 - val_accuracy: 0.9654 - val_precision: 0.9973 - val_recall: 0.9554
# Epoch 24/25
# 261/261 [==============================] - 46s 176ms/step - loss: 0.0825 - accuracy: 0.9734 - precision: 0.9915 - recall: 0.9728 - val_loss: 0.0774 - val_accuracy: 0.9788 - val_precision: 0.9973 - val_recall: 0.9737
# Epoch 25/25
# 261/261 [==============================] - 47s 180ms/step - loss: 0.1095 - accuracy: 0.9717 - precision: 0.9892 - recall: 0.9727 - val_loss: 0.0572 - val_accuracy: 0.9788 - val_precision: 0.9894 - val_recall: 0.9817

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 4s 113ms/step - loss: 1.2124 - accuracy: 0.7420 - precision: 0.7086 - recall: 0.9974
# Loss: 1.2124042510986328,
# Accuracy: 0.7419871687889099,
# Precision: 0.7085610032081604,
# Recall: 0.9974358677864075

# %% [markdown]
# ## 후기
# * 아담이 만능은 아니다
# * 이미지 모델링 같은 경우에는 다양한 augmentation 방법이 있으니 적용하기에 적절하다
# * 폐렴과 같이 의료 분야의 모델링은 accuracy보다 recall이 중요하다
# * 의료 분야에서의 데이터 전처리는 고려해야할 사항이 많다
